# %% [markdown]
# # read .excel, add few columns, save to .csv

# %%
import pandas as pd
results = pd.read_excel('/Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/tables/Results.xlsx',1)

# %%
results
# Out:
#                             SP  record  n_roi      min_t      max_t     min_f  \
# 0      Acrocephalus_baeticatus  432469      1   3.669150   3.717428  2347.826
# 1      Acrocephalus_baeticatus  432469      2   3.753637   3.813985  2391.304
# 2      Acrocephalus_baeticatus  432469      3   3.886402   3.934681  2304.348
# 3      Acrocephalus_baeticatus  432469      4   4.013133   4.055376  2347.826
# 4      Acrocephalus_baeticatus  432469      5   4.115724   4.176072  2304.348
# ...                        ...     ...    ...        ...        ...       ...
# 3370  Chalcomitra_senegalensis  708641     12  12.570700  12.691300  2037.228
# 3371  Chalcomitra_senegalensis  708641     13  13.238700  13.368600  2676.359
# 3372  Chalcomitra_senegalensis  708641     14  14.964200  15.089500  2876.087
# 3373  Chalcomitra_senegalensis  708641     15  15.915200  15.998700  2197.011
# 3374  Chalcomitra_senegalensis  708641     16  16.646600  16.776500  2716.304
#
# ...

# %%
results.loc[:,'id']=str(results.loc[:,'record'])
results = results.dropna()
results['sound_id']=results['record'].astype(int)
results['sound_id']=results['sound_id'].astype(str)
results['gen'] = results['SP'].apply(lambda x: x.split("_", 1)[0])
results['species'] = results['SP'].apply(lambda x: x.split("_", 1)[1])
results = results.drop(columns='SP')
results = results.reset_index(drop=True)

# %%
results
# Out:
#       record  n_roi      min_t      max_t     min_f     max_f      dt  \
# 0     432469      1   3.669150   3.717428  2347.826  2695.652  0.0483
# 1     432469      2   3.753637   3.813985  2391.304  2652.174  0.0603
# 2     432469      3   3.886402   3.934681  2304.348  2608.696  0.0483
# 3     432469      4   4.013133   4.055376  2347.826  2695.652  0.0422
# 4     432469      5   4.115724   4.176072  2304.348  2739.130  0.0603
# ...      ...    ...        ...        ...       ...       ...     ...
# 3370  708641     12  12.570700  12.691300  2037.228  3355.435  0.1206
# 3371  708641     13  13.238700  13.368600  2676.359  4034.511  0.1299
# 3372  708641     14  14.964200  15.089500  2876.087  4154.348  0.1252
# 3373  708641     15  15.915200  15.998700  2197.011  3395.380  0.0835
# 3374  708641     16  16.646600  16.776500  2716.304  4154.348  0.1299
#
#             df    APD          Family          Order    Biotope  \
# ...

# %%
results.to_csv('/Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/tables/annot.csv')

# %%
import pandas as pd
annots = pd.read_csv('/Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/tables/annot_new2.csv')

# %%
annots.biotope.unique()
# Out:
# array(['Grasslands', 'Forest', 'Wetlands', 'Woodlands', 'Marshlands'],
#       dtype=object)

# %%
annots['biotope'] = annots['biotope'].str.replace(" ", "")

# %%
annots['biotope'].unique()
# Out:
# array(['Grasslands', 'Forest', 'Wetlands', 'Woodlands', 'Marshlands'],
#       dtype=object)

# %%
annots.to_csv('/Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/tables/annot_new2.csv')
