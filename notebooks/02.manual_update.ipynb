# %% [markdown]
# #### This script gets all anotations coordinates from excel file
# ##### -computes acoustic features
# ##### -cleans and show metrics of data
# ##### -writes new .csv file for dash app#

# %%
import pandas as pd
from glob import glob
from pathlib import Path
import maad
import librosa
import soundfile as sf
import numpy as np
import warnings
warnings.filterwarnings(action='ignore')

# %%
datapath = '/Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/COUA/wav'
# datapath = '/Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto'
annot_path = '/Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/tables/annot.csv'

# %%
filelist = glob(datapath+'/**/*.wav', recursive = True)
df_data=pd.DataFrame()
for file in filelist:
    species = Path(file).parts[-2].rsplit(sep='_')[1]
    gen = Path(file).parts[-2].rsplit(sep='_')[0]
    df_data = df_data.append({'fullfilename': file,
                            'sound_id': Path(file).parts[-1][:-4],
                            'species': species,
                            'gen' : gen},
                            ignore_index=True)

# %%
df_data.to_csv('/Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/COUA/tables/df_soundfiles_paths.csv')

# %%
df_annot = pd.read_csv(annot_path)
# df_annot['sound_id']=df_annot['record'].astype(str)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [7], line 1
# ----> 1 df_annot = pd.read_csv(annot_path)
#
# File ~/Desktop/My_projects/Bioacoustics/Maputo_Dash/venv/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~/Desktop/My_projects/Bioacoustics/Maputo_Dash/venv/lib/python3.10/site-packages/pandas/util/_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
#     314         FutureWarning,
#     315         stacklevel=find_stack_level(inspect.currentframe()),
#     316     )
# --> 317 return func(*args, **kwargs)
#
# File ~/Desktop/My_projects/Bioacoustics/Maputo_Dash/venv/lib/python3.10/site-packages/pandas/io/parsers/readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File ~/Desktop/My_projects/Bioacoustics/Maputo_Dash/venv/lib/python3.10/site-packages/pandas/io/parsers/readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File ~/Desktop/My_projects/Bioacoustics/Maputo_Dash/venv/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File ~/Desktop/My_projects/Bioacoustics/Maputo_Dash/venv/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1729, in TextFileReader._make_engine(self, f, engine)
#    1727     is_text = False
#    1728     mode = "rb"
# -> 1729 self.handles = get_handle(
#    1730     f,
#    1731     mode,
#    1732     encoding=self.options.get("encoding", None),
#    1733     compression=self.options.get("compression", None),
#    1734     memory_map=self.options.get("memory_map", False),
#    1735     is_text=is_text,
#    1736     errors=self.options.get("encoding_errors", "strict"),
#    1737     storage_options=self.options.get("storage_options", None),
#    1738 )
#    1739 assert self.handles is not None
#    1740 f = self.handles.handle
#
# File ~/Desktop/My_projects/Bioacoustics/Maputo_Dash/venv/lib/python3.10/site-packages/pandas/io/common.py:857, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     852 elif isinstance(handle, str):
#     853     # Check whether the filename is to be opened in binary mode.
#     854     # Binary mode does not support 'encoding' and 'newline'.
#     855     if ioargs.encoding and "b" not in ioargs.mode:
#     856         # Encoding
# --> 857         handle = open(
#     858             handle,
#     859             ioargs.mode,
#     860             encoding=ioargs.encoding,
#     861             errors=errors,
#     862             newline="",
#     863         )
#     864     else:
#     865         # Binary mode
#     866         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/tables/annot.csv'

# %%
df_annot.shape
# Out:
# (3375, 17)

# %%
f"Theses are the missing species:{df_annot[df_annot.sound_id.astype(str).isin(df_data.sound_id)==False]['gen'].unique()}"
# Out:
# 'Theses are the missing species:[]'

# %%
df_annot[df_annot.sound_id.astype(str).isin(df_data.sound_id)].shape
# Out:
# (3375, 17)

# %%
df_annot['sound_id'] = df_annot['sound_id'].astype(str)
#filter annotations to .wav files we have in datasets/xenocanto/ (in case someone lost a wav file or an annotation)
df_annot = df_annot[df_annot.sound_id.isin(df_data.sound_id)]

# %%
df_annot.shape
# Out:
# (3375, 17)

# %%
# COMPUTE MAAD SPECTRAL AND TEMPORAL ALPHA FEATURES ON EACH OF THE MANNUALLY CONTOURED ROI
#list of features computed by maad, we filter them out later and compute them anyway....
SPECTRAL_FEATURES = ['MEANf', 'VARf', 'SKEWf', 'KURTf', 'NBPEAKS', 'LEQf',
                        'ENRf', 'BGNf', 'SNRf', 'Hf', 'EAS', 'ECU', 'ECV', 'EPS', 'EPS_KURT', 'EPS_SKEW', 'ACI',
                        'NDSI', 'rBA', 'AnthroEnergy', 'BioEnergy', 'BI', 'ROU', 'ADI', 'AEI', 'LFC', 'MFC', 'HFC',
                        'ACTspFract', 'ACTspCount', 'ACTspMean', 'EVNspFract', 'EVNspMean', 'EVNspCount',
                        'TFSD', 'H_Havrda', 'H_Renyi', 'H_pairedShannon', 'H_gamma', 'H_GiniSimpson', 'RAOQ',
                        'AGI', 'ROItotal', 'ROIcover']

TEMPORAL_FEATURES = ['ZCR', 'MEANt', 'VARt', 'SKEWt', 'KURTt',
                        'LEQt', 'BGNt', 'SNRt', 'MED', 'Ht', 'ACTtFraction', 'ACTtCount',
                        'ACTtMean', 'EVNtFraction', 'EVNtMean', 'EVNtCount']

# %%
df_annot_final = pd.DataFrame()
i=1
for file in filelist[:]:
    print(f'----------------------loading ({i}/{len(filelist)}): {file}...')
    i+=1
    #load .wav
    temp, sr = librosa.load(file, sr=None)
    sf.write('tmp.wav', temp, sr)
    s, fs = maad.sound.load('tmp.wav')
    maxAmp = np.abs(s).max()  # used to normalize
    #get spectro for tn and fn
    Sxx_power, tn, fn, ext = maad.sound.spectrogram(
        s/maxAmp, fs, flims=(0, 20000), display=False)
    
    #get ROI from annotation and convert x y to t f
    df_roi_annot = df_annot[df_annot['sound_id']==Path(file).parts[-1][:-4]].reset_index(drop=True)
    df_roi_annot = maad.util.format_features(df_roi_annot,tn,fn)
    df_rois_shape = pd.DataFrame()
    #if soundfile is anotated extract sound features from roi coordinates
    if len(df_roi_annot)>0:
        #INFO
        df_info = df_roi_annot.loc[:,['species','gen','Family','Order','Biotope','sound_id','n_roi']]    

        #SHAPES
        df_rois_shape_temp = maad.features.all_shape_features(
        s, fs, df_roi_annot, resolution='med', display=False)
        df_rois_shape = pd.concat([df_rois_shape,df_rois_shape_temp.reset_index(drop=True)],axis=0,ignore_index=True)
        
        #ALPHA INDICES
        df_temporal_features = pd.DataFrame(columns=TEMPORAL_FEATURES)
        df_spectral_features = pd.DataFrame(columns=SPECTRAL_FEATURES)
        
        for index, row in df_roi_annot.iloc[0:].iterrows():
            df_rois_all_features_temp = pd.DataFrame()
            s_trim = maad.sound.trim(
                s, fs, row.min_t, row.max_t)
            s_trim = s_trim - np.mean(s_trim)
            # s_trim = s_trim / np.max(np.abs(s_trim))
            
            try:
                Sxx_trim_power, tn, fn, ext = maad.sound.spectrogram(s_trim, fs,
                                                                        verbose=False, display=False,
                                                                        savefig=None)

                spectral_features_temp, _ = maad.features.all_spectral_alpha_indices(
                        Sxx_trim_power, tn, fn, display=False)
                        
                temporal_features_temp = maad.features.all_temporal_alpha_indices(s_trim, fs)

            except:
                print(str(file)+': error at index (chunk too small?): '+str(index)+'\n s_trim looks like:'+str(s_trim.shape)+'\n temporal size:'+str(row.min_t - row.max_t))

            df_spectral_features = pd.concat([df_spectral_features,spectral_features_temp], axis=0,ignore_index=True)
            df_temporal_features = pd.concat([df_temporal_features,temporal_features_temp], axis=0,ignore_index=True)
            df_rois_all_features_temp = pd.concat([df_spectral_features,df_temporal_features],axis=1).reset_index(drop=True)
        
        df_annot_final_temp = pd.concat([df_info,df_rois_all_features_temp,df_rois_shape],axis=1)
        df_annot_final = pd.concat([df_annot_final,df_annot_final_temp],axis=0)
    else:
        print('no annotation available')
        pass
    
    
df_annot_final= df_annot_final.reset_index(drop=True)
    
df_annot_final = df_annot_final.T.drop_duplicates().T
# Out:
# ----------------------loading (1/127): /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Calendulauda_africanoides/449420.wav...
# number of rois : 33
# ----------------------loading (2/127): /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Cisticola_galactotes/452901.wav...
# no annotation available
# ----------------------loading (3/127): /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Cisticola_galactotes/201332.wav...
# no annotation available
# ----------------------loading (4/127): /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Cisticola_galactotes/710853.wav...
# no annotation available
# ----------------------loading (5/127): /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Cyanomitra_olivacea/721728.wav...
# number of rois : 22
# ----------------------loading (6/127): /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Burhinus_vermiculatus/701253.wav...
# number of rois : 2
# ----------------------loading (7/127): /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Chrysococcyx_klaas/448614.wav...
# number of rois : 38
# ----------------------loading (8/127): /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Acrocephalus_baeticatus/453372.wav...
# no annotation available
# ----------------------loading (9/127): /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Acrocephalus_baeticatus/432472.wav...
# number of rois : 178
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Acrocephalus_baeticatus/432472.wav: error at index (chunk too small?): 142
#  s_trim looks like:(1035,)
#  temporal size:-0.02156382000000079
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Acrocephalus_baeticatus/432472.wav: error at index (chunk too small?): 143
#  s_trim looks like:(1035,)
#  temporal size:-0.021563818999997153
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Acrocephalus_baeticatus/432472.wav: error at index (chunk too small?): 147
#  s_trim looks like:(1035,)
#  temporal size:-0.02156382000000079
# ----------------------loading (10/127): /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Acrocephalus_baeticatus/432471.wav...
# number of rois : 101
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Acrocephalus_baeticatus/432471.wav: error at index (chunk too small?): 47
#  s_trim looks like:(1497,)
#  temporal size:-0.03118671799999717
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Acrocephalus_baeticatus/432471.wav: error at index (chunk too small?): 79
#  s_trim looks like:(1497,)
#  temporal size:-0.031186718000000724
# ----------------------loading (11/127): /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Acrocephalus_baeticatus/432684.wav...
# no annotation available
# ----------------------loading (12/127): /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Acrocephalus_baeticatus/432681.wav...
# no annotation available
# ----------------------loading (13/127): /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Acrocephalus_baeticatus/432680.wav...
# no annotation available
# ----------------------loading (14/127): /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Acrocephalus_baeticatus/432469.wav...
# number of rois : 52
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Acrocephalus_baeticatus/432469.wav: error at index (chunk too small?): 5
#  s_trim looks like:(1449,)
#  temporal size:-0.03017393100000021
# ----------------------loading (15/127): /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Acrocephalus_baeticatus/432682.wav...
# no annotation available
# ----------------------loading (16/127): /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Macronyx_ameliae/316661.wav...
# no annotation available
# ----------------------loading (17/127): /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Macronyx_ameliae/316658.wav...
# no annotation available
# ----------------------loading (18/127): /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Chlorophoneus_olivaceus/104021.wav...
# number of rois : 6
# ----------------------loading (19/127): /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Anthreptes_reichenowi/201496.wav...
# number of rois : 234
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Anthreptes_reichenowi/201496.wav: error at index (chunk too small?): 15
#  s_trim looks like:(1060,)
#  temporal size:-0.04804840300000013
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Anthreptes_reichenowi/201496.wav: error at index (chunk too small?): 16
#  s_trim looks like:(1324,)
#  temporal size:-0.06006050399999996
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Anthreptes_reichenowi/201496.wav: error at index (chunk too small?): 17
#  s_trim looks like:(530,)
#  temporal size:-0.024024202000000106
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Anthreptes_reichenowi/201496.wav: error at index (chunk too small?): 18
#  s_trim looks like:(795,)
#  temporal size:-0.036036302999999936
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Anthreptes_reichenowi/201496.wav: error at index (chunk too small?): 20
#  s_trim looks like:(1324,)
#  temporal size:-0.06006050500000004
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Anthreptes_reichenowi/201496.wav: error at index (chunk too small?): 22
#  s_trim looks like:(1324,)
#  temporal size:-0.06006050399999996
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Anthreptes_reichenowi/201496.wav: error at index (chunk too small?): 59
#  s_trim looks like:(1324,)
#  temporal size:-0.060060504999999154
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Anthreptes_reichenowi/201496.wav: error at index (chunk too small?): 61
#  s_trim looks like:(1059,)
#  temporal size:-0.04804840300000279
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Anthreptes_reichenowi/201496.wav: error at index (chunk too small?): 64
#  s_trim looks like:(1324,)
#  temporal size:-0.06006050399999907
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Anthreptes_reichenowi/201496.wav: error at index (chunk too small?): 71
#  s_trim looks like:(1325,)
#  temporal size:-0.06006050399999907
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Anthreptes_reichenowi/201496.wav: error at index (chunk too small?): 72
#  s_trim looks like:(1325,)
#  temporal size:-0.060060504000002624
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Anthreptes_reichenowi/201496.wav: error at index (chunk too small?): 74
#  s_trim looks like:(1325,)
#  temporal size:-0.060060504999999154
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Anthreptes_reichenowi/201496.wav: error at index (chunk too small?): 114
#  s_trim looks like:(1324,)
#  temporal size:-0.060060504999999154
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Anthreptes_reichenowi/201496.wav: error at index (chunk too small?): 115
#  s_trim looks like:(1325,)
#  temporal size:-0.060060504999999154
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Anthreptes_reichenowi/201496.wav: error at index (chunk too small?): 116
#  s_trim looks like:(1324,)
#  temporal size:-0.06006050399999907
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Anthreptes_reichenowi/201496.wav: error at index (chunk too small?): 117
#  s_trim looks like:(1324,)
#  temporal size:-0.060060504000002624
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Anthreptes_reichenowi/201496.wav: error at index (chunk too small?): 133
#  s_trim looks like:(1324,)
#  temporal size:-0.06006050399999907
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Anthreptes_reichenowi/201496.wav: error at index (chunk too small?): 163
#  s_trim looks like:(1324,)
#  temporal size:-0.06006050399999907
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Anthreptes_reichenowi/201496.wav: error at index (chunk too small?): 164
#  s_trim looks like:(1324,)
#  temporal size:-0.06006050399999907
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Anthreptes_reichenowi/201496.wav: error at index (chunk too small?): 165
#  s_trim looks like:(1324,)
#  temporal size:-0.06006050399999907
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Anthreptes_reichenowi/201496.wav: error at index (chunk too small?): 166
#  s_trim looks like:(795,)
#  temporal size:-0.03603630299999594
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Anthreptes_reichenowi/201496.wav: error at index (chunk too small?): 167
#  s_trim looks like:(1324,)
#  temporal size:-0.06006050399999907
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Anthreptes_reichenowi/201496.wav: error at index (chunk too small?): 168
#  s_trim looks like:(1059,)
#  temporal size:-0.04804840399999932
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Anthreptes_reichenowi/201496.wav: error at index (chunk too small?): 169
#  s_trim looks like:(795,)
#  temporal size:-0.03603630199999941
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Anthreptes_reichenowi/201496.wav: error at index (chunk too small?): 170
#  s_trim looks like:(1059,)
#  temporal size:-0.04804840399999932
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Anthreptes_reichenowi/201496.wav: error at index (chunk too small?): 171
#  s_trim looks like:(1191,)
#  temporal size:-0.05405445400000275
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Anthreptes_reichenowi/201496.wav: error at index (chunk too small?): 172
#  s_trim looks like:(662,)
#  temporal size:-0.030030251999995983
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Anthreptes_reichenowi/201496.wav: error at index (chunk too small?): 194
#  s_trim looks like:(795,)
#  temporal size:-0.03603630199999941
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Anthreptes_reichenowi/201496.wav: error at index (chunk too small?): 231
#  s_trim looks like:(1324,)
#  temporal size:-0.06006050500000981
# ----------------------loading (20/127): /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Rallus_caerulescens/399267.wav...
# number of rois : 45
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Rallus_caerulescens/399267.wav: error at index (chunk too small?): 0
#  s_trim looks like:(1177,)
#  temporal size:-0.026699999999999946
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Rallus_caerulescens/399267.wav: error at index (chunk too small?): 2
#  s_trim looks like:(697,)
#  temporal size:-0.015800000000000036
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Rallus_caerulescens/399267.wav: error at index (chunk too small?): 3
#  s_trim looks like:(697,)
#  temporal size:-0.015800000000000036
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Rallus_caerulescens/399267.wav: error at index (chunk too small?): 4
#  s_trim looks like:(833,)
#  temporal size:-0.01890000000000014
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Rallus_caerulescens/399267.wav: error at index (chunk too small?): 5
#  s_trim looks like:(556,)
#  temporal size:-0.012600000000000167
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Rallus_caerulescens/399267.wav: error at index (chunk too small?): 6
#  s_trim looks like:(834,)
#  temporal size:-0.01890000000000014
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Rallus_caerulescens/399267.wav: error at index (chunk too small?): 7
#  s_trim looks like:(1111,)
#  temporal size:-0.02520000000000011
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Rallus_caerulescens/399267.wav: error at index (chunk too small?): 9
#  s_trim looks like:(1040,)
#  temporal size:-0.023599999999999843
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Rallus_caerulescens/399267.wav: error at index (chunk too small?): 44
#  s_trim looks like:(1389,)
#  temporal size:-0.031500000000001194
# ----------------------loading (21/127): /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Asio_capensis/685451.wav...
# number of rois : 52
# ----------------------loading (22/127): /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/403523.wav...
# no annotation available
# ----------------------loading (23/127): /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav...
# number of rois : 259
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 0
#  s_trim looks like:(643,)
#  temporal size:-0.013399999999998968
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 1
#  s_trim looks like:(480,)
#  temporal size:-0.009999999999999787
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 2
#  s_trim looks like:(485,)
#  temporal size:-0.01010000000000133
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 3
#  s_trim looks like:(485,)
#  temporal size:-0.01010000000000133
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 4
#  s_trim looks like:(567,)
#  temporal size:-0.01180000000000092
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 5
#  s_trim looks like:(259,)
#  temporal size:-0.005399999999999849
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 6
#  s_trim looks like:(595,)
#  temporal size:-0.012399999999999523
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 7
#  s_trim looks like:(283,)
#  temporal size:-0.00590000000000046
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 8
#  s_trim looks like:(427,)
#  temporal size:-0.008899999999998798
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 9
#  s_trim looks like:(288,)
#  temporal size:-0.006000000000000227
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 10
#  s_trim looks like:(341,)
#  temporal size:-0.00709999999999944
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 11
#  s_trim looks like:(370,)
#  temporal size:-0.007700000000003371
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 12
#  s_trim looks like:(254,)
#  temporal size:-0.005299999999998306
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 13
#  s_trim looks like:(312,)
#  temporal size:-0.006500000000002615
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 14
#  s_trim looks like:(428,)
#  temporal size:-0.008900000000000574
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 15
#  s_trim looks like:(369,)
#  temporal size:-0.007699999999999818
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 16
#  s_trim looks like:(398,)
#  temporal size:-0.00829999999999842
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 17
#  s_trim looks like:(394,)
#  temporal size:-0.008199999999998653
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 18
#  s_trim looks like:(369,)
#  temporal size:-0.007699999999999818
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 19
#  s_trim looks like:(369,)
#  temporal size:-0.007699999999999818
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 20
#  s_trim looks like:(398,)
#  temporal size:-0.00829999999999842
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 21
#  s_trim looks like:(197,)
#  temporal size:-0.00409999999999755
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 22
#  s_trim looks like:(509,)
#  temporal size:-0.010600000000000165
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 23
#  s_trim looks like:(369,)
#  temporal size:-0.007699999999999818
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 24
#  s_trim looks like:(399,)
#  temporal size:-0.00829999999999842
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 25
#  s_trim looks like:(231,)
#  temporal size:-0.004799999999999471
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 26
#  s_trim looks like:(283,)
#  temporal size:-0.005899999999996908
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 27
#  s_trim looks like:(226,)
#  temporal size:-0.004699999999999704
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 28
#  s_trim looks like:(341,)
#  temporal size:-0.0071000000000012164
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 29
#  s_trim looks like:(168,)
#  temporal size:-0.0034999999999953957
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 30
#  s_trim looks like:(428,)
#  temporal size:-0.008900000000004127
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 31
#  s_trim looks like:(254,)
#  temporal size:-0.005299999999998306
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 32
#  s_trim looks like:(226,)
#  temporal size:-0.004699999999999704
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 33
#  s_trim looks like:(370,)
#  temporal size:-0.007699999999999818
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 34
#  s_trim looks like:(197,)
#  temporal size:-0.004100000000001103
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 35
#  s_trim looks like:(398,)
#  temporal size:-0.00829999999999842
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 36
#  s_trim looks like:(283,)
#  temporal size:-0.005899999999996908
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 37
#  s_trim looks like:(202,)
#  temporal size:-0.004199999999997317
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 38
#  s_trim looks like:(255,)
#  temporal size:-0.005299999999998306
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 39
#  s_trim looks like:(226,)
#  temporal size:-0.004699999999999704
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 40
#  s_trim looks like:(196,)
#  temporal size:-0.004100000000001103
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 41
#  s_trim looks like:(259,)
#  temporal size:-0.005400000000001626
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 42
#  s_trim looks like:(197,)
#  temporal size:-0.004100000000001103
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 43
#  s_trim looks like:(202,)
#  temporal size:-0.004199999999997317
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 44
#  s_trim looks like:(283,)
#  temporal size:-0.005900000000004013
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 45
#  s_trim looks like:(1287,)
#  temporal size:-0.026799999999999935
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 50
#  s_trim looks like:(1454,)
#  temporal size:-0.030299999999999994
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 51
#  s_trim looks like:(1080,)
#  temporal size:-0.022499999999999964
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 52
#  s_trim looks like:(1046,)
#  temporal size:-0.021800000000000264
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 53
#  s_trim looks like:(1502,)
#  temporal size:-0.031299999999999883
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 55
#  s_trim looks like:(1301,)
#  temporal size:-0.027100000000000346
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 56
#  s_trim looks like:(1248,)
#  temporal size:-0.0259999999999998
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 57
#  s_trim looks like:(979,)
#  temporal size:-0.020399999999999974
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 58
#  s_trim looks like:(576,)
#  temporal size:-0.01200000000000001
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 59
#  s_trim looks like:(543,)
#  temporal size:-0.01130000000000031
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 60
#  s_trim looks like:(408,)
#  temporal size:-0.00849999999999973
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 61
#  s_trim looks like:(504,)
#  temporal size:-0.010500000000000398
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 62
#  s_trim looks like:(442,)
#  temporal size:-0.009199999999999875
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 63
#  s_trim looks like:(643,)
#  temporal size:-0.013399999999998968
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 64
#  s_trim looks like:(811,)
#  temporal size:-0.016899999999999693
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 65
#  s_trim looks like:(471,)
#  temporal size:-0.009800000000000253
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 66
#  s_trim looks like:(1248,)
#  temporal size:-0.02599999999999625
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 67
#  s_trim looks like:(1454,)
#  temporal size:-0.030299999999996885
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 68
#  s_trim looks like:(1248,)
#  temporal size:-0.02599999999999625
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 69
#  s_trim looks like:(1517,)
#  temporal size:-0.03160000000000451
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 70
#  s_trim looks like:(1281,)
#  temporal size:-0.02669999999999817
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 71
#  s_trim looks like:(1353,)
#  temporal size:-0.028199999999998226
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 73
#  s_trim looks like:(1353,)
#  temporal size:-0.028199999999998226
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 75
#  s_trim looks like:(1455,)
#  temporal size:-0.03030000000000399
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 78
#  s_trim looks like:(1421,)
#  temporal size:-0.029599999999994964
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 79
#  s_trim looks like:(1516,)
#  temporal size:-0.03160000000000451
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 80
#  s_trim looks like:(1282,)
#  temporal size:-0.02669999999999817
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 83
#  s_trim looks like:(1382,)
#  temporal size:-0.028799999999996828
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 84
#  s_trim looks like:(946,)
#  temporal size:-0.019699999999993167
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 85
#  s_trim looks like:(1517,)
#  temporal size:-0.03159999999999741
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 86
#  s_trim looks like:(1080,)
#  temporal size:-0.022500000000000853
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 89
#  s_trim looks like:(1215,)
#  temporal size:-0.025300000000001432
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 90
#  s_trim looks like:(1382,)
#  temporal size:-0.028799999999996828
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 91
#  s_trim looks like:(1214,)
#  temporal size:-0.025300000000001432
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 92
#  s_trim looks like:(1147,)
#  temporal size:-0.02389999999999759
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 93
#  s_trim looks like:(1219,)
#  temporal size:-0.025399999999997647
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 94
#  s_trim looks like:(979,)
#  temporal size:-0.02039999999999509
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 95
#  s_trim looks like:(979,)
#  temporal size:-0.020400000000002194
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 96
#  s_trim looks like:(744,)
#  temporal size:-0.01549999999999585
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 97
#  s_trim looks like:(1012,)
#  temporal size:-0.02109999999999701
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 98
#  s_trim looks like:(1051,)
#  temporal size:-0.021899999999995146
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 99
#  s_trim looks like:(811,)
#  temporal size:-0.016899999999999693
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 100
#  s_trim looks like:(1181,)
#  temporal size:-0.02459999999999951
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 102
#  s_trim looks like:(1249,)
#  temporal size:-0.026000000000003354
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 103
#  s_trim looks like:(1449,)
#  temporal size:-0.03020000000000067
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 104
#  s_trim looks like:(1454,)
#  temporal size:-0.030299999999996885
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 105
#  s_trim looks like:(1253,)
#  temporal size:-0.026099999999999568
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 106
#  s_trim looks like:(1353,)
#  temporal size:-0.028199999999998226
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 107
#  s_trim looks like:(1214,)
#  temporal size:-0.025299999999994327
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 108
#  s_trim looks like:(1248,)
#  temporal size:-0.026000000000003354
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 109
#  s_trim looks like:(1248,)
#  temporal size:-0.026000000000003354
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 110
#  s_trim looks like:(1315,)
#  temporal size:-0.02740000000000009
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 111
#  s_trim looks like:(1282,)
#  temporal size:-0.026700000000005275
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 112
#  s_trim looks like:(1382,)
#  temporal size:-0.028799999999996828
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 113
#  s_trim looks like:(1219,)
#  temporal size:-0.025400000000004752
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 114
#  s_trim looks like:(1421,)
#  temporal size:-0.02960000000000207
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 115
#  s_trim looks like:(1051,)
#  temporal size:-0.02190000000000225
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 116
#  s_trim looks like:(1219,)
#  temporal size:-0.025399999999997647
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 117
#  s_trim looks like:(1080,)
#  temporal size:-0.022500000000000853
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 118
#  s_trim looks like:(1454,)
#  temporal size:-0.030299999999996885
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 119
#  s_trim looks like:(1214,)
#  temporal size:-0.025300000000001432
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 120
#  s_trim looks like:(1316,)
#  temporal size:-0.02740000000000009
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 121
#  s_trim looks like:(1320,)
#  temporal size:-0.02750000000000341
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 122
#  s_trim looks like:(1349,)
#  temporal size:-0.028100000000002012
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 123
#  s_trim looks like:(1051,)
#  temporal size:-0.02190000000000225
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 124
#  s_trim looks like:(1488,)
#  temporal size:-0.030999999999998806
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 125
#  s_trim looks like:(1282,)
#  temporal size:-0.02669999999999817
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 126
#  s_trim looks like:(1455,)
#  temporal size:-0.030299999999996885
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 128
#  s_trim looks like:(1454,)
#  temporal size:-0.03030000000000399
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 129
#  s_trim looks like:(1253,)
#  temporal size:-0.026099999999999568
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 130
#  s_trim looks like:(946,)
#  temporal size:-0.019700000000000273
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 131
#  s_trim looks like:(1248,)
#  temporal size:-0.02599999999999625
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 132
#  s_trim looks like:(1248,)
#  temporal size:-0.02599999999999625
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 133
#  s_trim looks like:(1281,)
#  temporal size:-0.026700000000005275
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 134
#  s_trim looks like:(1214,)
#  temporal size:-0.025300000000001432
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 135
#  s_trim looks like:(1353,)
#  temporal size:-0.028199999999998226
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 136
#  s_trim looks like:(1013,)
#  temporal size:-0.02109999999999701
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 137
#  s_trim looks like:(1114,)
#  temporal size:-0.023200000000002774
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 138
#  s_trim looks like:(912,)
#  temporal size:-0.01899999999999835
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 139
#  s_trim looks like:(1013,)
#  temporal size:-0.02109999999999701
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 140
#  s_trim looks like:(1281,)
#  temporal size:-0.02669999999999817
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 141
#  s_trim looks like:(1215,)
#  temporal size:-0.025299999999994327
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 142
#  s_trim looks like:(912,)
#  temporal size:-0.01899999999999835
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 143
#  s_trim looks like:(912,)
#  temporal size:-0.01899999999999835
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 144
#  s_trim looks like:(1114,)
#  temporal size:-0.02319999999999567
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 145
#  s_trim looks like:(980,)
#  temporal size:-0.020400000000002194
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 146
#  s_trim looks like:(1320,)
#  temporal size:-0.027499999999996305
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 147
#  s_trim looks like:(1185,)
#  temporal size:-0.024700000000009936
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 148
#  s_trim looks like:(1383,)
#  temporal size:-0.028800000000003934
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 150
#  s_trim looks like:(1488,)
#  temporal size:-0.03100000000000591
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 153
#  s_trim looks like:(1253,)
#  temporal size:-0.026099999999999568
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 155
#  s_trim looks like:(1421,)
#  temporal size:-0.02960000000000207
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 157
#  s_trim looks like:(1387,)
#  temporal size:-0.028899999999993042
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 158
#  s_trim looks like:(1214,)
#  temporal size:-0.025300000000001432
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 159
#  s_trim looks like:(1118,)
#  temporal size:-0.023299999999991883
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 160
#  s_trim looks like:(1421,)
#  temporal size:-0.029599999999987858
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 161
#  s_trim looks like:(1454,)
#  temporal size:-0.030300000000011096
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 162
#  s_trim looks like:(1522,)
#  temporal size:-0.03170000000000073
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 163
#  s_trim looks like:(1455,)
#  temporal size:-0.030299999999996885
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 164
#  s_trim looks like:(1046,)
#  temporal size:-0.02179999999999893
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 166
#  s_trim looks like:(778,)
#  temporal size:-0.016200000000011983
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 168
#  s_trim looks like:(777,)
#  temporal size:-0.016199999999997772
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 169
#  s_trim looks like:(1483,)
#  temporal size:-0.03089999999998838
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 170
#  s_trim looks like:(1282,)
#  temporal size:-0.026700000000005275
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 171
#  s_trim looks like:(1488,)
#  temporal size:-0.0309999999999917
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 172
#  s_trim looks like:(1215,)
#  temporal size:-0.025300000000001432
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 173
#  s_trim looks like:(1517,)
#  temporal size:-0.03159999999999741
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 174
#  s_trim looks like:(1147,)
#  temporal size:-0.02389999999999759
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Paragallinula_angulata/407075.wav: error at index (chunk too small?): 175
#  s_trim looks like:(1522,)
# ...
# number of rois : 9
# ----------------------loading (106/127): /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Apalis_ruddi/201315.wav...
# number of rois : 166
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Apalis_ruddi/201315.wav: error at index (chunk too small?): 2
#  s_trim looks like:(663,)
#  temporal size:-0.030064544000000026
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Apalis_ruddi/201315.wav: error at index (chunk too small?): 3
#  s_trim looks like:(1326,)
#  temporal size:-0.06012908599999989
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Apalis_ruddi/201315.wav: error at index (chunk too small?): 5
#  s_trim looks like:(1326,)
#  temporal size:-0.06012908699999997
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Apalis_ruddi/201315.wav: error at index (chunk too small?): 6
#  s_trim looks like:(1325,)
#  temporal size:-0.06012908699999997
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Apalis_ruddi/201315.wav: error at index (chunk too small?): 7
#  s_trim looks like:(1326,)
#  temporal size:-0.06012908699999997
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Apalis_ruddi/201315.wav: error at index (chunk too small?): 8
#  s_trim looks like:(1326,)
#  temporal size:-0.06012908699999997
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Apalis_ruddi/201315.wav: error at index (chunk too small?): 10
#  s_trim looks like:(1412,)
#  temporal size:-0.06400103600000051
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Apalis_ruddi/201315.wav: error at index (chunk too small?): 12
#  s_trim looks like:(1507,)
#  temporal size:-0.06832850799999957
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Apalis_ruddi/201315.wav: error at index (chunk too small?): 14
#  s_trim looks like:(1506,)
#  temporal size:-0.06832850799999957
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Apalis_ruddi/201315.wav: error at index (chunk too small?): 17
#  s_trim looks like:(1099,)
#  temporal size:-0.04984191800000026
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Apalis_ruddi/201315.wav: error at index (chunk too small?): 18
#  s_trim looks like:(1130,)
#  temporal size:-0.05124638100000034
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Apalis_ruddi/201315.wav: error at index (chunk too small?): 19
#  s_trim looks like:(1507,)
#  temporal size:-0.06832850799999957
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Apalis_ruddi/201315.wav: error at index (chunk too small?): 20
#  s_trim looks like:(1318,)
#  temporal size:-0.05978744399999947
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Apalis_ruddi/201315.wav: error at index (chunk too small?): 22
#  s_trim looks like:(1130,)
#  temporal size:-0.051246380999998564
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Apalis_ruddi/201315.wav: error at index (chunk too small?): 23
#  s_trim looks like:(1130,)
#  temporal size:-0.05124638100000034
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Apalis_ruddi/201315.wav: error at index (chunk too small?): 24
#  s_trim looks like:(1319,)
#  temporal size:-0.05978744499999955
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Apalis_ruddi/201315.wav: error at index (chunk too small?): 25
#  s_trim looks like:(1319,)
#  temporal size:-0.05978744399999947
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Apalis_ruddi/201315.wav: error at index (chunk too small?): 27
#  s_trim looks like:(1318,)
#  temporal size:-0.05978744399999947
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Apalis_ruddi/201315.wav: error at index (chunk too small?): 28
#  s_trim looks like:(1318,)
#  temporal size:-0.05978744399999947
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Apalis_ruddi/201315.wav: error at index (chunk too small?): 29
#  s_trim looks like:(1318,)
#  temporal size:-0.05978744399999947
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Apalis_ruddi/201315.wav: error at index (chunk too small?): 30
#  s_trim looks like:(1507,)
#  temporal size:-0.06832850799999868
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Apalis_ruddi/201315.wav: error at index (chunk too small?): 32
#  s_trim looks like:(1507,)
#  temporal size:-0.06832850800000045
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Apalis_ruddi/201315.wav: error at index (chunk too small?): 34
#  s_trim looks like:(941,)
#  temporal size:-0.04270531799999944
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Apalis_ruddi/201315.wav: error at index (chunk too small?): 35
#  s_trim looks like:(1318,)
#  temporal size:-0.05978744399999947
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Apalis_ruddi/201315.wav: error at index (chunk too small?): 36
#  s_trim looks like:(1130,)
#  temporal size:-0.05124638100000034
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Apalis_ruddi/201315.wav: error at index (chunk too small?): 39
#  s_trim looks like:(1319,)
#  temporal size:-0.05978744399999947
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Apalis_ruddi/201315.wav: error at index (chunk too small?): 40
#  s_trim looks like:(1507,)
#  temporal size:-0.06832850800000045
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Apalis_ruddi/201315.wav: error at index (chunk too small?): 41
#  s_trim looks like:(1318,)
#  temporal size:-0.05978744499999955
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Apalis_ruddi/201315.wav: error at index (chunk too small?): 42
#  s_trim looks like:(941,)
#  temporal size:-0.042705316999999354
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Apalis_ruddi/201315.wav: error at index (chunk too small?): 44
#  s_trim looks like:(1413,)
#  temporal size:-0.06405797600000085
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Apalis_ruddi/201315.wav: error at index (chunk too small?): 51
#  s_trim looks like:(753,)
#  temporal size:-0.03416425400000023
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Apalis_ruddi/201315.wav: error at index (chunk too small?): 52
#  s_trim looks like:(942,)
#  temporal size:-0.042705316999999354
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Apalis_ruddi/201315.wav: error at index (chunk too small?): 69
#  s_trim looks like:(753,)
#  temporal size:-0.03416425400000023
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Apalis_ruddi/201315.wav: error at index (chunk too small?): 70
#  s_trim looks like:(942,)
#  temporal size:-0.042705316999999354
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Apalis_ruddi/201315.wav: error at index (chunk too small?): 71
#  s_trim looks like:(1130,)
#  temporal size:-0.051246380999998564
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Apalis_ruddi/201315.wav: error at index (chunk too small?): 81
#  s_trim looks like:(1130,)
#  temporal size:-0.051246380999998564
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Apalis_ruddi/201315.wav: error at index (chunk too small?): 82
#  s_trim looks like:(1507,)
#  temporal size:-0.06832850800000045
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Apalis_ruddi/201315.wav: error at index (chunk too small?): 86
#  s_trim looks like:(942,)
#  temporal size:-0.042705316999999354
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Apalis_ruddi/201315.wav: error at index (chunk too small?): 92
#  s_trim looks like:(1507,)
#  temporal size:-0.06832850800000045
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Apalis_ruddi/201315.wav: error at index (chunk too small?): 93
#  s_trim looks like:(1130,)
#  temporal size:-0.051246380999998564
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Apalis_ruddi/201315.wav: error at index (chunk too small?): 94
#  s_trim looks like:(753,)
#  temporal size:-0.03416425400000023
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Apalis_ruddi/201315.wav: error at index (chunk too small?): 100
#  s_trim looks like:(1130,)
#  temporal size:-0.051246380999998564
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Apalis_ruddi/201315.wav: error at index (chunk too small?): 101
#  s_trim looks like:(1319,)
#  temporal size:-0.05978744399999769
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Apalis_ruddi/201315.wav: error at index (chunk too small?): 104
#  s_trim looks like:(1506,)
#  temporal size:-0.06832850800000045
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Apalis_ruddi/201315.wav: error at index (chunk too small?): 105
#  s_trim looks like:(1319,)
#  temporal size:-0.05978744500000133
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Apalis_ruddi/201315.wav: error at index (chunk too small?): 106
#  s_trim looks like:(941,)
#  temporal size:-0.042705316999999354
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Apalis_ruddi/201315.wav: error at index (chunk too small?): 114
#  s_trim looks like:(1130,)
#  temporal size:-0.051246380999998564
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Apalis_ruddi/201315.wav: error at index (chunk too small?): 130
#  s_trim looks like:(1130,)
#  temporal size:-0.051246380999998564
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Apalis_ruddi/201315.wav: error at index (chunk too small?): 131
#  s_trim looks like:(1130,)
#  temporal size:-0.051246380999998564
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Apalis_ruddi/201315.wav: error at index (chunk too small?): 134
#  s_trim looks like:(1507,)
#  temporal size:-0.06832850699999682
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Apalis_ruddi/201315.wav: error at index (chunk too small?): 135
#  s_trim looks like:(1318,)
#  temporal size:-0.059787444000001244
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Apalis_ruddi/201315.wav: error at index (chunk too small?): 136
#  s_trim looks like:(1318,)
#  temporal size:-0.059787444000001244
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Apalis_ruddi/201315.wav: error at index (chunk too small?): 139
#  s_trim looks like:(1130,)
#  temporal size:-0.051246380000002034
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Apalis_ruddi/201315.wav: error at index (chunk too small?): 141
#  s_trim looks like:(941,)
#  temporal size:-0.042705316999999354
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Apalis_ruddi/201315.wav: error at index (chunk too small?): 161
#  s_trim looks like:(1507,)
#  temporal size:-0.06832850699999682
# ----------------------loading (107/127): /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Gallinago_nigripennis/415839.wav...
# no annotation available
# ----------------------loading (108/127): /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Gallinago_nigripennis/701493.wav...
# no annotation available
# ----------------------loading (109/127): /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Upupa_africana/59751.wav...
# number of rois : 41
# ----------------------loading (110/127): /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Camaroptera_brachyura/59744.wav...
# no annotation available
# ----------------------loading (111/127): /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Camaroptera_brachyura/721734.wav...
# no annotation available
# ----------------------loading (112/127): /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Camaroptera_brachyura/453382.wav...
# no annotation available
# ----------------------loading (113/127): /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Notopholia_corusca/444708.wav...
# no annotation available
# ----------------------loading (114/127): /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Caprimulgus_pectoralis/705357.wav...
# number of rois : 14
# ----------------------loading (115/127): /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Centropus_grillii/457592.wav...
# number of rois : 18
# ----------------------loading (116/127): /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Quelea_erythrops/391097.wav...
# no annotation available
# ----------------------loading (117/127): /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Quelea_erythrops/391200.wav...
# no annotation available
# ----------------------loading (118/127): /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Chalcomitra_senegalensis/708641.wav...
# number of rois : 16
# ----------------------loading (119/127): /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Chalcomitra_senegalensis/721748.wav...
# number of rois : 46
# ----------------------loading (120/127): /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Cisticola_chiniana/444840.wav...
# number of rois : 15
# ----------------------loading (121/127): /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Smithornis_capensis/201484.wav...
# number of rois : 4
# ----------------------loading (122/127): /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Ardea_cinerea/59739.wav...
# number of rois : 1
# ----------------------loading (123/127): /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Pycnonotus_tricolor/523243.wav...
# no annotation available
# ----------------------loading (124/127): /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Pycnonotus_tricolor/523234.wav...
# no annotation available
# ----------------------loading (125/127): /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Vanellus_lugubris/411262.wav...
# number of rois : 65
# /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Vanellus_lugubris/411262.wav: error at index (chunk too small?): 51
#  s_trim looks like:(1507,)
#  temporal size:-0.03140000000000143
# ----------------------loading (126/127): /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Vanellus_lugubris/394493.wav...
# no annotation available
# ----------------------loading (127/127): /Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Treron_calvus/104019.wav...
# number of rois : 4

# %% [markdown]
# # Check your data

# %%
df_annot_final.loc[:,['species','gen','Family','Order','Biotope','sound_id']].dropna()
# Out:
#            species           gen        Family            Order     Biotope  \
# 0     africanoides  Calendulauda     Alaudidae    Passeriformes  Grasslands
# 1     africanoides  Calendulauda     Alaudidae    Passeriformes  Grasslands
# 2     africanoides  Calendulauda     Alaudidae    Passeriformes  Grasslands
# 3     africanoides  Calendulauda     Alaudidae    Passeriformes  Grasslands
# 4     africanoides  Calendulauda     Alaudidae    Passeriformes  Grasslands
# ...            ...           ...           ...              ...         ...
# 3370      lugubris      Vanellus  Charadriidae  Charadriiformes  Grasslands
# 3371        calvus        Treron    Colombidae    Colombiformes   Woodlands
# 3372        calvus        Treron    Colombidae    Colombiformes   Woodlands
# 3373        calvus        Treron    Colombidae    Colombiformes   Woodlands
# 3374        calvus        Treron    Colombidae    Colombiformes   Woodlands
#
#      sound_id
# 0      449420
# 1      449420
# 2      449420
# 3      449420
# 4      449420
# ...       ...
# 3370   411262
# 3371   104019
# 3372   104019
# 3373   104019
# 3374   104019
#
# [3375 rows x 6 columns]

# %%
df_annot_final.loc[:,['df','bandwidth_f','bandwidth_y','df','duration_t','duration_x','area_xy', 'centroid_f', 'centroid_t',
       'area_tf']]
# Out:
#             df  bandwidth_f bandwidth_y        df duration_t duration_x  \
# 0     2620.059  2627.050781         0.0  2620.059    0.12771  60.998821
# 1     2179.059  2196.386719         0.0  2179.059    0.20898   50.99102
# 2     1530.529  1507.324219         0.0  1530.529    0.05805  34.992472
# 3     2256.882  2239.453125         0.0  2256.882    0.12771  51.989478
# 4     1011.706   990.527344         0.0  1011.706    0.06966  23.010975
# ...        ...          ...         ...       ...        ...        ...
# 3370   387.097      421.875         0.0   387.097   0.245333   9.002667
# 3371  1884.712  1894.921875         0.0  1884.712   0.464399  44.001814
# 3372   1820.46  1851.855469         0.0   1820.46   0.394739  43.003356
# 3373  1927.546  1937.988281         0.0  1927.546   0.394739  45.000272
# 3374  1734.791  1765.722656         0.0  1734.791   0.417959   41.00644
#
#      area_xy   centroid_f centroid_t area_tf
# 0       2684  5124.902344   3.030204   335.5
# 1       3672  5426.367188   3.215964   459.0
# 2        700  4306.640625   3.494603    87.5
# 3       2288  6244.628906   3.622313   286.0
# 4        552     6890.625   3.726803    69.0
# ...      ...          ...        ...     ...
# 3370     828       1875.0     30.144   103.5
# 3371    7040  1464.257812   1.741497   880.0
# 3372    5848  1464.257812   4.435011   731.0
# 3373    6120  1550.390625   8.846803   765.0
# 3374    5904  1593.457031  11.702857   738.0
#
# [3375 rows x 10 columns]

# %%
df_annot_final.sound_id.nunique()
# Out:
# 51

# %%
#check for NaNs
for column in df_annot_final.columns.values[:]:
    if df_annot_final[str(column)].isna().sum() > 0:
        print([str(column)])
# Out:
# ['ACTspMean']
# ['LEQt']
# ['ACTtMean']
# ['shp_001']
# ['shp_002']
# ['shp_003']
# ['shp_004']
# ['shp_005']
# ['shp_006']
# ['shp_007']
# ['shp_008']
# ['shp_009']
# ['shp_010']
# ['shp_011']
# ['shp_012']
# ['shp_013']
# ['shp_014']
# ['shp_015']
# ['shp_016']
# ['shp_017']
# ['shp_018']
# ['shp_019']
# ['shp_020']
# ['shp_021']
# ['shp_022']
# ['shp_023']
# ['shp_024']
# ['shp_025']
# ['shp_026']
# ['shp_027']
# ['shp_028']
# ['shp_029']
# ['shp_030']
# ['shp_031']
# ['shp_032']
# ['shp_033']
# ['shp_034']
# ['shp_035']
# ['shp_036']
# ['shp_037']
# ['shp_038']
# ['shp_039']
# ['shp_040']
# ['shp_041']
# ['shp_042']
# ['shp_043']
# ['shp_044']
# ['shp_045']
# ['shp_046']
# ['shp_047']
# ['shp_048']

# %%
df_annot_final.columns[:100]
# Out:
# Index(['species', 'gen', 'Family', 'Order', 'Biotope', 'sound_id', 'n_roi',
#        'MEANf', 'VARf', 'SKEWf', 'KURTf', 'NBPEAKS', 'LEQf', 'ENRf', 'BGNf',
#        'SNRf', 'Hf', 'EAS', 'ECU', 'ECV', 'EPS', 'EPS_KURT', 'EPS_SKEW', 'ACI',
#        'NDSI', 'rBA', 'AnthroEnergy', 'BioEnergy', 'BI', 'ROU', 'ADI', 'AEI',
#        'LFC', 'MFC', 'HFC', 'ACTspFract', 'ACTspCount', 'ACTspMean',
#        'EVNspFract', 'EVNspMean', 'EVNspCount', 'TFSD', 'H_Havrda', 'H_Renyi',
#        'H_pairedShannon', 'H_gamma', 'H_GiniSimpson', 'RAOQ', 'AGI',
#        'ROItotal', 'ROIcover', 'ZCR', 'MEANt', 'VARt', 'SKEWt', 'KURTt',
#        'LEQt', 'BGNt', 'SNRt', 'MED', 'Ht', 'ACTtFraction', 'ACTtCount',
#        'ACTtMean', 'EVNtFraction', 'EVNtMean', 'EVNtCount', 'Unnamed: 0',
#        'record', 'min_t', 'max_t', 'min_f', 'max_f', 'dt', 'df', 'APD', 'id',
#        'min_y', 'min_x', 'max_y', 'max_x', 'shp_001', 'shp_002', 'shp_003',
#        'shp_004', 'shp_005', 'shp_006', 'shp_007', 'shp_008', 'shp_009',
#        'shp_010', 'shp_011', 'shp_012', 'shp_013', 'shp_014', 'shp_015',
#        'shp_016', 'shp_017', 'shp_018', 'shp_019'],
#       dtype='object')

# %%
df_annot_final.columns[100:]
# Out:
# Index(['shp_020', 'shp_021', 'shp_022', 'shp_023', 'shp_024', 'shp_025',
#        'shp_026', 'shp_027', 'shp_028', 'shp_029', 'shp_030', 'shp_031',
#        'shp_032', 'shp_033', 'shp_034', 'shp_035', 'shp_036', 'shp_037',
#        'shp_038', 'shp_039', 'shp_040', 'shp_041', 'shp_042', 'shp_043',
#        'shp_044', 'shp_045', 'shp_046', 'shp_047', 'shp_048', 'centroid_y',
#        'centroid_x', 'duration_x', 'bandwidth_y', 'area_xy', 'centroid_f',
#        'centroid_t', 'duration_t', 'bandwidth_f', 'area_tf'],
#       dtype='object')

# %% [markdown]
# # Reduce to interesting and non-null columns

# %%
df_annot_final.biotope.unique()
# Out:
# array(['Grasslands', 'Forest', 'Wetlands', 'Woodlands', 'Marshlands',
#        'Woodlands '], dtype=object)

# %%
df_annot_final =df_annot_final.loc[:,['species','gen', 'Family', 'Order','Biotope', 'sound_id','min_t', 'max_t', 'min_f', 'max_f','dt', 'df', 'centroid_f','centroid_t', 'duration_t', 'bandwidth_f', 'area_tf','shp_002', 'shp_003', 'shp_004', 'shp_005', 'shp_006', 'shp_007','shp_008', 'shp_009', 'shp_010', 'shp_011', 'shp_012', 'shp_013','shp_014', 'shp_015', 'shp_016', 'shp_017', 'shp_018', 'shp_019','shp_020', 'shp_021', 'shp_022', 'shp_023', 'shp_024', 'shp_025','shp_026', 'shp_027', 'shp_028', 'shp_029', 'shp_030', 'shp_031','shp_032', 'shp_033', 'shp_034', 'shp_035', 'shp_036', 'shp_037','shp_038', 'shp_039', 'shp_040', 'shp_041', 'shp_042', 'shp_043','shp_044', 'shp_045', 'shp_046', 'shp_047', 'shp_048','MEANf', 'VARf', 'SKEWf', 'KURTf', 'NBPEAKS', 'LEQf', 'ENRf', 'BGNf', 'SNRf', 'Hf', 'EAS', 'ECU', 'ECV', 'EPS', 'EPS_KURT', 'EPS_SKEW', 'ACI', 'NDSI', 'ROU',  'ZCR', 'MEANt', 'VARt', 'SKEWt', 'KURTt', 'Ht']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [20], line 1
# ----> 1 df_annot_final =df_annot_final.loc[:,['species','gen', 'Family', 'Order','Biotope', 'sound_id','n_roi','min_t', 'max_t', 'min_f', 'max_f','dt', 'df', 'centroid_f','centroid_t', 'duration_t', 'bandwidth_f', 'area_tf','shp_002', 'shp_003', 'shp_004', 'shp_005', 'shp_006', 'shp_007','shp_008', 'shp_009', 'shp_010', 'shp_011', 'shp_012', 'shp_013','shp_014', 'shp_015', 'shp_016', 'shp_017', 'shp_018', 'shp_019','shp_020', 'shp_021', 'shp_022', 'shp_023', 'shp_024', 'shp_025','shp_026', 'shp_027', 'shp_028', 'shp_029', 'shp_030', 'shp_031','shp_032', 'shp_033', 'shp_034', 'shp_035', 'shp_036', 'shp_037','shp_038', 'shp_039', 'shp_040', 'shp_041', 'shp_042', 'shp_043','shp_044', 'shp_045', 'shp_046', 'shp_047', 'shp_048','MEANf', 'VARf', 'SKEWf', 'KURTf', 'NBPEAKS', 'LEQf', 'ENRf', 'BGNf', 'SNRf', 'Hf', 'EAS', 'ECU', 'ECV', 'EPS', 'EPS_KURT', 'EPS_SKEW', 'ACI', 'NDSI', 'ROU',  'ZCR', 'MEANt', 'VARt', 'SKEWt', 'KURTt', 'Ht']]
#
# File ~/Desktop/My_projects/Bioacoustics/Maputo_Dash/venv/lib/python3.10/site-packages/pandas/core/indexing.py:1068, in _LocationIndexer.__getitem__(self, key)
#    1066     if self._is_scalar_access(key):
#    1067         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1068     return self._getitem_tuple(key)
#    1069 else:
#    1070     # we by definition only have the 0th axis
#    1071     axis = self.axis or 0
#
# File ~/Desktop/My_projects/Bioacoustics/Maputo_Dash/venv/lib/python3.10/site-packages/pandas/core/indexing.py:1257, in _LocIndexer._getitem_tuple(self, tup)
#    1254 if self._multi_take_opportunity(tup):
#    1255     return self._multi_take(tup)
# -> 1257 return self._getitem_tuple_same_dim(tup)
#
# File ~/Desktop/My_projects/Bioacoustics/Maputo_Dash/venv/lib/python3.10/site-packages/pandas/core/indexing.py:925, in _LocationIndexer._getitem_tuple_same_dim(self, tup)
#     922 if com.is_null_slice(key):
#     923     continue
# --> 925 retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     926 # We should never have retval.ndim < self.ndim, as that should
#     927 #  be handled by the _getitem_lowerdim call above.
#     928 assert retval.ndim == self.ndim
#
# File ~/Desktop/My_projects/Bioacoustics/Maputo_Dash/venv/lib/python3.10/site-packages/pandas/core/indexing.py:1302, in _LocIndexer._getitem_axis(self, key, axis)
#    1299     if hasattr(key, "ndim") and key.ndim > 1:
#    1300         raise ValueError("Cannot index with multidimensional key")
# -> 1302     return self._getitem_iterable(key, axis=axis)
#    1304 # nested tuple slicing
#    1305 if is_nested_tuple(key, labels):
#
# File ~/Desktop/My_projects/Bioacoustics/Maputo_Dash/venv/lib/python3.10/site-packages/pandas/core/indexing.py:1240, in _LocIndexer._getitem_iterable(self, key, axis)
#    1237 self._validate_key(key, axis)
#    1239 # A collection of keys
# -> 1240 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1241 return self.obj._reindex_with_indexers(
#    1242     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1243 )
#
# File ~/Desktop/My_projects/Bioacoustics/Maputo_Dash/venv/lib/python3.10/site-packages/pandas/core/indexing.py:1433, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1430 ax = self.obj._get_axis(axis)
#    1431 axis_name = self.obj._get_axis_name(axis)
# -> 1433 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1435 return keyarr, indexer
#
# File ~/Desktop/My_projects/Bioacoustics/Maputo_Dash/venv/lib/python3.10/site-packages/pandas/core/indexes/base.py:6108, in Index._get_indexer_strict(self, key, axis_name)
#    6105 else:
#    6106     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6108 self._raise_if_missing(keyarr, indexer, axis_name)
#    6110 keyarr = self.take(indexer)
#    6111 if isinstance(key, Index):
#    6112     # GH 42790 - Preserve name from an Index
#
# File ~/Desktop/My_projects/Bioacoustics/Maputo_Dash/venv/lib/python3.10/site-packages/pandas/core/indexes/base.py:6171, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6168     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6170 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6171 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['gen', 'Family', 'Order', 'Biotope', 'n_roi'] not in index"

# %%
#this aint a test anymore

df_annot_final = df_annot_final.rename(columns={"Family": "family","Order":"order",'Biotope':'biotope','gen':'genus'})

df_annot_final.to_csv('/Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/tables/annot_new2.csv')

# %%
df_annot_final.dropna(axis=1, how='any').columns

# %%
df_annot_final[df_temporal_features.columns].isna().sum().sum()

# %%
df_annot_final[df_spectral_features.columns].isna().sum().sum()

# %%
df_annot_final[df_rois_shape.columns].isna().sum().sum()

# %%
df_annot_final.isna().sum().sum()

# %%
df_rois_shape
