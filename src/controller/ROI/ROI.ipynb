# %%
from ROI import find_ROIs_soundfile, compute_ROI_all_features

import warnings
warnings.filterwarnings(action='ignore')

# %%
wavpath = '/Users/Paul/Paul/Desktop/My_projects/Bioacoustics/Maputo_Dash/datasets/wav/xenocanto/Numenius_phaeopus/308218.wav'

# %%
df_rois,s,fs = find_ROIs_soundfile(path=wavpath, display=True, mode_bin='relative', param1=10, param2=0.9)

# %%
df_rois_all_features = compute_ROI_all_features(s,fs,df_rois=df_rois)
# Out:
# number of rois : 18

# %%
df_rois_all_features.describe()
# Out:
#             min_y       min_x       max_y       max_x         min_f  \
# count   18.000000   18.000000   18.000000   18.000000     18.000000
# mean   136.888889  105.833333  186.500000  128.611111   5895.312500
# std     73.043008   34.017729  109.634285   39.647178   3145.699865
# min     53.000000   48.000000   82.000000   70.000000   2282.519531
# 25%     81.000000   76.250000  109.250000  101.500000   3488.378906
# 50%    120.000000  106.000000  150.500000  133.500000   5167.968750
# 75%    164.500000  131.750000  225.750000  142.750000   7084.423828
# max    327.000000  174.000000  498.000000  219.000000  14082.714844
#
#            min_t         max_f      max_t    shp_001    shp_002  ...  \
# count  18.000000     18.000000  18.000000  18.000000  18.000000  ...
# mean    1.240333   8031.884766   1.504782   0.117727   0.120414  ...
# std     0.394945   4721.554661   0.460303   0.022715   0.019956  ...
# min     0.568889   3531.445312   0.824308   0.089510   0.096452  ...
# ...

# %%
df_rois_all_features.head(10)
# Out:
#   labelID    label  min_y  min_x  max_y  max_x        min_f     min_t  \
# 0       1  unknown     53     48    103     70  2282.519531  0.568889
# 1       2  unknown     63     91    113    172  2713.183594  1.068118
# 2       3  unknown     69     77     82     84  2971.582031  0.905578
# 3       4  unknown     69    174    104    219  2971.582031  2.031746
# 4       5  unknown     81     72     90     77  3488.378906  0.847528
# 5       6  unknown     81     77    162    103  3488.378906  0.905578
# 6       7  unknown     99    121    108    124  4263.574219  1.416417
# 7       8  unknown    101    107    121    117  4349.707031  1.253878
# 8       9  unknown    104     74    115     77  4478.906250  0.870748
# 9      10  unknown    136    122    145    129  5857.031250  1.428027
#
#          max_f     max_t  ...      BGNt      SNRt       MED        Ht  \
# 0  4435.839844  0.824308  ... -3.130455  0.217572  0.697392  0.979079
# ...

# %%
df_rois_all_features.columns
# Out:
# Index(['labelID', 'label', 'min_y', 'min_x', 'max_y', 'max_x', 'min_f',
#        'min_t', 'max_f', 'max_t',
#        ...
#        'BGNt', 'SNRt', 'MED', 'Ht', 'ACTtFraction', 'ACTtCount', 'ACTtMean',
#        'EVNtFraction', 'EVNtMean', 'EVNtCount'],
#       dtype='object', length=128)
